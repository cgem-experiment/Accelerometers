# %%
# %run v2_UDP_socket.py
# Out:
#  Bind successful. Listening for data...
# Listening for UDP packets from 10.20.3.3:8 on port 12345...
# Folder created at  C:\Users\natal\June_2025_Accelerometer\20250619T120208_cgem_accel
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:08.605728
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:08.804772
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:08.997260
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:09.204090
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:09.403064
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:09.600875
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:09.800817
# b'\xa5Z' ('10.20.3.3', 8)
# ...
# 2 samples written to file. First value: 2025-06-19 12:02:09.993914
# b'\xa5Z' ('10.20.3.3', 8)
# ...

# %%
# Out:
# ✅ Listening for UDP packets on port 55151...
